# %% [markdown]
# # Simple Chaos

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Image
# %matplotlib inline

# %% [markdown]
# Write a python function `cobweb(f, x0, n, xmin, xmax, ymin, ymax)` to draw a cobweb plot of fixed point iteration, where
# ~~~
# --------- --------------------------------------
#  `f`      name of function to plot
#  `x0`       starting point value of x
#  `n`        number of fixed point iterations
#  `xmin`     minimum value for $x$-axis on plot
#  `xmax`     maximum value for $x$-axis on plot
#  `ymin`     minimum value for $y$-axis on plot
#  `ymax`     maximum value for $y$-axis on plot
#
# ~~~
#
# This is a reminder of what a typical cobweb plot looks like (not for the function you are working with though, so your cobweb will look different).

# %%
Image(filename='img/cobweb.png',width=400)

# %% [markdown]
# Demonstrate that your cobweb plot works with the function call
#
#     cobweb(cos, 1.0, 200,0, 1.5, 0, 1)

# %%
f = lambda x: np.cos(x)
def cobweb(f,x0,n,xmin,xmax,ymin,ymax):
    plt.axhline(linewidth=1.0, color="black")
    plt.axvline(linewidth=1.0, color="black")
    plt.ylim((ymin,ymax))
    indep = np.linspace(xmin,xmax,5000)
    diag = lambda x: x
    plt.plot(indep,f(indep),'b')
    plt.plot(indep,diag(indep),'black')
    y0 = f(x0)
    for i in range(n):
        plt.hlines(y0, x0, y0,'r')
        x0 = y0
        y0 = f(x0)
        plt.vlines(x0, x0,y0,'r')
    

    return 0

cobweb(f,1,200,0,1.5,0,1)
# Out:
# 0

# %% [markdown]
# **Problem 2**
# Explore the convergence of the logistic map using your cobweb plot.
#
# Run the function you wrote in problem 1 using the function $f(x) = rx(1 − x)$ by defining the following three functions in python:
#
#     f(x) = r*x*(1-x)
#     g(x) =  f(f(x))
#     h(x) = f(f(f(x))
#
# In particular, explore what happens by plotting the cobwebs for values of $r$ as it varies from 3.8 to 3.85. You may need to make 20 to 30 plots over this region and compare them as $r$ is varied to see what is happening. First look at $F$, then $G$, then $H$. What do you think is happening, and why do you think it is happening? Is there some range of values it is occurring over? You will be graded on how you justify your answer.

# %%
r = 3.82
f = lambda x: r*x*(1-x)
g = lambda x: f(f(x))
h = lambda x: f(f(f(x)))

# %%
def webbyr(r,iterations,x0,n,xmin,xmax,ymin,ymax):
    plt.figure(figsize=(40,3))
    plt.suptitle('r='+str(r),size='xx-large')
    for j in range(4):
        f = lambda x: r*x*(1-x)
        g = lambda x: f(f(x))
        h = lambda x: f(f(f(x)))
        plt.subplot(1, 12, j+1)
        plt.subplot(1, 12, j+1).axes.get_xaxis().set_visible(False)
        plt.subplot(1, 12, j+1).axes.get_yaxis().set_visible(False)
        cobweb(f,x0+j*.25,n,xmin,xmax,ymin,ymax)
        plt.subplot(1, 12, j+5)
        plt.subplot(1, 12, j+5).axes.get_xaxis().set_visible(False)
        plt.subplot(1, 12, j+5).axes.get_yaxis().set_visible(False)
        cobweb(g,x0+j*.25,n,xmin,xmax,ymin,ymax)
        plt.subplot(1, 12, j+9)
        plt.subplot(1, 12, j+9).axes.get_xaxis().set_visible(False)
        plt.subplot(1, 12, j+9).axes.get_yaxis().set_visible(False)
        cobweb(h,x0+j*.25,n,xmin,xmax,ymin,ymax)

        return
    
for i in range(35):
    r = 3.800+.0002*i
    webbyr(r,4,0.01,200,0,1, 0, 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-1945ee084c7c> in <module>()
#      23 for i in range(35):
#      24     r = 3.800+.0002*i
# ---> 25     webbyr(r,4,0.01,200,0,1, 0, 1)
#
# <ipython-input-15-1945ee084c7c> in webbyr(r, iterations, x0, n, xmin, xmax, ymin, ymax)
#       9         plt.subplot(1, 12, j+1).axes.get_xaxis().set_visible(False)
#      10         plt.subplot(1, 12, j+1).axes.get_yaxis().set_visible(False)
# ---> 11         cobweb(f,x0+j*.25,n,xmin,xmax,ymin,ymax)
#      12         plt.subplot(1, 12, j+5)
#      13         plt.subplot(1, 12, j+5).axes.get_xaxis().set_visible(False)
#
# <ipython-input-12-a3799618a35f> in cobweb(f, x0, n, xmin, xmax, ymin, ymax)
#      10     y0 = f(x0)
#      11     for i in range(n):
# ---> 12         plt.hlines(y0, x0, y0,'r')
#      13         x0 = y0
#      14         y0 = f(x0)
#
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hlines(y, xmin, xmax, colors, linestyles, label, hold, **kwargs)
#    2933     try:
#    2934         ret = ax.hlines(y, xmin, xmax, colors=colors, linestyles=linestyles,
# -> 2935                         label=label, **kwargs)
#    2936         draw_if_interactive()
#    2937     finally:
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hlines(self, y, xmin, xmax, colors, linestyles, label, **kwargs)
#     968                  for thisxmin, thisxmax, thisy in zip(xmin, xmax, y)]
#     969         coll = mcoll.LineCollection(verts, colors=colors,
# --> 970                                     linestyles=linestyles, label=label)
#     971         self.add_collection(coll, autolim=False)
#     972         coll.update(kwargs)
#
# /usr/local/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, segments, linewidths, colors, antialiaseds, linestyles, offsets, transOffset, norm, cmap, pickradius, zorder, **kwargs)
#    1060             **kwargs)
#    1061
# -> 1062         self.set_segments(segments)
#    1063
#    1064     def set_segments(self, segments):
#
# /usr/local/lib/python2.7/site-packages/matplotlib/collections.pyc in set_segments(self, segments)
#    1074         if self._uniform_offsets is not None:
#    1075             _segments = self._add_offsets(_segments)
# -> 1076         self._paths = [mpath.Path(seg) for seg in _segments]
#    1077
#    1078     set_verts = set_segments  # for compatibility with PolyCollection
#
# /usr/local/lib/python2.7/site-packages/matplotlib/path.pyc in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     135             vertices = vertices.astype(np.float_).filled(np.nan)
#     136         else:
# --> 137             vertices = np.asarray(vertices, np.float_)
#     138
#     139         if codes is not None:
#
# /usr/local/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     460
#     461     """
# --> 462     return array(a, dtype, copy=False, order=order)
#     463
#     464 def asanyarray(a, dtype=None, order=None):
#
# KeyboardInterrupt:

# %%
def webbyr0(x0,n,xmin,xmax,ymin,ymax):
    r = 0
    for i in range(12):
        plt.figure(figsize=(40,3))
        for j in range(10):
            r = r+.05
            f = lambda x: r*x*(1-x)
            plt.subplot(1, 10, j+1)
            plt.title('r='+str(r),size='xx-large')
            plt.subplot(1, 10, j+1).axes.get_xaxis().set_visible(False)
            plt.subplot(1, 10, j+1).axes.get_yaxis().set_visible(False)
            cobweb(f,x0,n,xmin,xmax,ymin,ymax)
        plt.show()
        
    return 

webbyr0(0.01,200,0,1, 0, 1)
